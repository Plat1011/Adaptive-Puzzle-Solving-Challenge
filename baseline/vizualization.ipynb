# %%
from gym import Fifteen2DEnv 
from viz_utils import show_fifteen, beam_search

env = Fifteen2DEnv()

state, actions = env.scramble(length=42, seed=42)
actions = beam_search(env)

show_fifteen(state, actions)

# %%
from gym import LightsOutEnv
from viz_utils import show_lights_out

env = LightsOutEnv()
state, actions = env.scramble(length=42, seed=42)
actions = beam_search(env)

show_lights_out(state, actions)

# %%
from gym import RotateSlideEnv
from viz_utils import show_rotate_slide 

env = RotateSlideEnv()
state, actions = env.scramble(length=42, seed=42)
actions = beam_search(env)

show_rotate_slide(state, actions)
